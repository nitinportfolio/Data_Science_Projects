# %%
# embedding layer - 1x56x100
# 56 - Features
# 283 - Rows
# For evey word of row 1 will go into 100 neurons of next layer
# 283 - vocab words
# 283 * 100 = 28300
# For every row & for evry word in each row we have a 100 dimensional vector

# %%
# NOw output of this will go into the LSTM for each timestamp t = 1, t = 2 ....t = 56
# This will have a shape [1,150]
# Shape of ht is same as number of nodes

#4 * ((x+h)*h+h)
# h - 150
# x - 100

4 * (( 100
  +  150
 ) *  150
  +  150
 )

#https://www.kaggle.com/code/kmkarakaya/lstm-understanding-the-number-of-parameters
# Out:
# 150600

# %%
# Now dense layer will have 283 outputs
283*150+283 
# Weights + Bias
# Out:
# 42733

# %%
with open('./data/sherlock.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
text
# Out:
# '\n\n\n\n                        THE ADVENTURES OF SHERLOCK HOLMES\n\n                               Arthur Conan Doyle\n\n\n\n                                Table of contents\n\n               A Scandal in Bohemia\n               The Red-Headed League\n               A Case of Identity\n               The Boscombe Valley Mystery\n               The Five Orange Pips\n               The Man with the Twisted Lip\n               The Adventure of the Blue Carbuncle\n               The Adventure of the Speckled Band\n               The Adventure of the Engineer\'s Thumb\n               The Adventure of the Noble Bachelor\n               The Adventure of the Beryl Coronet\n               The Adventure of the Copper Beeches\n\n\n\n\n\n\n\n\n\n\n                              A SCANDAL IN BOHEMIA\n\n\n\n\n\n                                Table of contents\n                                     Chapter 1\n                                     Chapter 2\n                                     Cha
# ...

# %%
len(text)
# Out:
# 610871

# %%
tokenizer.fit_on_texts([text])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'i': 3,
#  'to': 4,
#  'of': 5,
#  'a': 6,
#  'in': 7,
#  'that': 8,
#  'it': 9,
#  'he': 10,
#  'you': 11,
#  'was': 12,
#  'his': 13,
#  'is': 14,
#  'my': 15,
#  'have': 16,
#  'as': 17,
#  'with': 18,
#  'had': 19,
#  'which': 20,
#  'at': 21,
#  'for': 22,
#  'but': 23,
#  'me': 24,
#  'not': 25,
#  'be': 26,
#  'we': 27,
#  'from': 28,
#  'there': 29,
#  'this': 30,
#  'said': 31,
#  'upon': 32,
#  'so': 33,
#  'holmes': 34,
#  'him': 35,
#  'her': 36,
#  'she': 37,
#  "'": 38,
#  'very': 39,
#  'your': 40,
#  'been': 41,
#  'all': 42,
#  'on': 43,
#  'no': 44,
#  'what': 45,
#  'one': 46,
#  'then': 47,
#  'were': 48,
#  'by': 49,
#  'are': 50,
#  'an': 51,
#  'would': 52,
#  'out': 53,
#  'when': 54,
#  'up': 55,
#  'man': 56,
#  'could': 57,
#  'has': 58,
#  'do': 59,
#  'into': 60,
#  'mr': 61,
#  'who': 62,
#  'little': 63,
#  'will': 64,
#  'if': 65,
#  'some': 66,
#  'now': 67,
#  'see': 68,
#  'down': 69,
#  'should': 70,
#  'our': 71,
# ...

# %%
type(tokenizer.word_index)
# Out:
# dict

# %%
len(tokenizer.word_index)
# Out:
# 8231

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('the', 16854),
#              ('adventures', 18),
#              ('of', 7980),
#              ('sherlock', 294),
#              ('holmes', 1335),
#              ('arthur', 51),
#              ('conan', 3),
#              ('doyle', 3),
#              ('table', 159),
#              ('contents', 18),
#              ('a', 7920),
#              ('scandal', 39),
#              ('in', 5292),
#              ('bohemia', 36),
#              ('red', 153),
#              ('headed', 72),
#              ('league', 51),
#              ('case', 351),
#              ('identity', 12),
#              ('boscombe', 48),
#              ('valley', 21),
#              ('mystery', 66),
#              ('five', 120),
#              ('orange', 33),
#              ('pips', 36),
#              ('man', 873),
#              ('with', 2490),
#              ('twisted', 30),
#              ('lip', 36),
#              ('adventure', 57),
#              ('blue', 78),
#              ('carbuncle', 21),
# ...

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('the', 16854),
#              ('adventures', 18),
#              ('of', 7980),
#              ('sherlock', 294),
#              ('holmes', 1335),
#              ('arthur', 51),
#              ('conan', 3),
#              ('doyle', 3),
#              ('table', 159),
#              ('contents', 18),
#              ('a', 7920),
#              ('scandal', 39),
#              ('in', 5292),
#              ('bohemia', 36),
#              ('red', 153),
#              ('headed', 72),
#              ('league', 51),
#              ('case', 351),
#              ('identity', 12),
#              ('boscombe', 48),
#              ('valley', 21),
#              ('mystery', 66),
#              ('five', 120),
#              ('orange', 33),
#              ('pips', 36),
#              ('man', 873),
#              ('with', 2490),
#              ('twisted', 30),
#              ('lip', 36),
#              ('adventure', 57),
#              ('blue', 78),
#              ('carbuncle', 21),
# ...

# %%
# The count of all words found in the input text is stored in an OrderedDict
type(tokenizer.word_counts)
# Out:
# collections.OrderedDict

# %%
sum([x for _,x in tokenizer.word_counts.items()])
# Out:
# 317637

# %%
a = 0
for i in tokenizer.word_counts.items():
    print(i)
    a = a+1
    print(a)
# Out:
# ('the', 16854)
# 1
# ('adventures', 18)
# 2
# ('of', 7980)
# 3
# ('sherlock', 294)
# 4
# ('holmes', 1335)
# 5
# ('arthur', 51)
# 6
# ('conan', 3)
# 7
# ('doyle', 3)
# 8
# ('table', 159)
# 9
# ('contents', 18)
# 10
# ('a', 7920)
# 11
# ('scandal', 39)
# 12
# ('in', 5292)
# 13
# ('bohemia', 36)
# 14
# ('red', 153)
# 15
# ('headed', 72)
# 16
# ('league', 51)
# 17
# ('case', 351)
# 18
# ('identity', 12)
# 19
# ('boscombe', 48)
# 20
# ('valley', 21)
# 21
# ('mystery', 66)
# 22
# ('five', 120)
# 23
# ('orange', 33)
# 24
# ('pips', 36)
# 25
# ('man', 873)
# 26
# ('with', 2490)
# 27
# ('twisted', 30)
# 28
# ('lip', 36)
# 29
# ('adventure', 57)
# 30
# ('blue', 78)
# 31
# ('carbuncle', 21)
# 32
# ('speckled', 15)
# 33
# ('band', 42)
# 34
# ("engineer's", 6)
# 35
# ('thumb', 51)
# 36
# ('noble', 42)
# 37
# ('bachelor', 24)
# 38
# ('beryl', 12)
# 39
# ('coronet', 84)
# 40
# ('copper', 39)
# 41
# ('beeches', 36)
# 42
# ('chapter', 21)
# 43
# ('1', 6)
# 44
# ('2', 9)
# 45
# ('3', 6)
# 46
# ...

# %%
a = 0
for i,j in tokenizer.word_counts.items():
    print(i)
    print(j)
    a = a+1
    #print(a)
# Out:
# the
# 16854
# adventures
# 18
# of
# 7980
# sherlock
# 294
# holmes
# 1335
# arthur
# 51
# conan
# 3
# doyle
# 3
# table
# 159
# contents
# 18
# a
# 7920
# scandal
# 39
# in
# 5292
# bohemia
# 36
# red
# 153
# headed
# 72
# league
# 51
# case
# 351
# identity
# 12
# boscombe
# 48
# valley
# 21
# mystery
# 66
# five
# 120
# orange
# 33
# pips
# 36
# man
# 873
# with
# 2490
# twisted
# 30
# lip
# 36
# adventure
# 57
# blue
# 78
# carbuncle
# 21
# speckled
# 15
# band
# 42
# engineer's
# 6
# thumb
# 51
# noble
# 42
# bachelor
# 24
# beryl
# 12
# coronet
# 84
# copper
# 39
# beeches
# 36
# chapter
# 21
# 1
# 6
# 2
# 9
# 3
# 6
# i
# 8874
# to
# 8232
# she
# 1275
# is
# 3363
# always
# 174
# woman
# 180
# have
# 2766
# seldom
# 18
# heard
# 339
# him
# 1302
# mention
# 6
# her
# 1290
# under
# 129
# any
# 393
# other
# 441
# name
# 186
# his
# 3474
# eyes
# 261
# eclipses
# 3
# and
# 9006
# predominates
# 3
# whole
# 135
# sex
# 3
# it
# 5076
# was
# 4233
# not
# 1902
# that
# 5208
# he
# ...

# %%
type(text)
# Out:
# str

# %%
#from pathlib import Path
#temp = Path("./data/sherlock.txt").read_text()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([text])

# %%
# This will show what number is assigned to each token
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'i': 3,
#  'to': 4,
#  'of': 5,
#  'a': 6,
#  'in': 7,
#  'that': 8,
#  'it': 9,
#  'he': 10,
#  'you': 11,
#  'was': 12,
#  'his': 13,
#  'is': 14,
#  'my': 15,
#  'have': 16,
#  'as': 17,
#  'with': 18,
#  'had': 19,
#  'which': 20,
#  'at': 21,
#  'for': 22,
#  'but': 23,
#  'me': 24,
#  'not': 25,
#  'be': 26,
#  'we': 27,
#  'from': 28,
#  'there': 29,
#  'this': 30,
#  'said': 31,
#  'upon': 32,
#  'so': 33,
#  'holmes': 34,
#  'him': 35,
#  'her': 36,
#  'she': 37,
#  "'": 38,
#  'very': 39,
#  'your': 40,
#  'been': 41,
#  'all': 42,
#  'on': 43,
#  'no': 44,
#  'what': 45,
#  'one': 46,
#  'then': 47,
#  'were': 48,
#  'by': 49,
#  'are': 50,
#  'an': 51,
#  'would': 52,
#  'out': 53,
#  'when': 54,
#  'up': 55,
#  'man': 56,
#  'could': 57,
#  'has': 58,
#  'do': 59,
#  'into': 60,
#  'mr': 61,
#  'who': 62,
#  'little': 63,
#  'will': 64,
#  'if': 65,
#  'some': 66,
#  'now': 67,
#  'see': 68,
#  'down': 69,
#  'should': 70,
#  'our': 71,
# ...

# %%
len(tokenizer.word_index)
# Out:
# 8199

# %%
for sentence in text.split("/n"):
    print(sentence)
# Out:
#                         THE ADVENTURES OF SHERLOCK HOLMES
#
#                                Arthur Conan Doyle
#
#
#
#                                 Table of contents
#
#                A Scandal in Bohemia
#                The Red-Headed League
#                A Case of Identity
#                The Boscombe Valley Mystery
#                The Five Orange Pips
#                The Man with the Twisted Lip
#                The Adventure of the Blue Carbuncle
#                The Adventure of the Speckled Band
#                The Adventure of the Engineer's Thumb
#                The Adventure of the Noble Bachelor
#                The Adventure of the Beryl Coronet
#                The Adventure of the Copper Beeches
#
#
#
#
#
#
#
#
#
#
#                               A SCANDAL IN BOHEMIA
#
#
#
#
#
#                                 Table of contents
#                                      Chapter 1
#                                      Chapter 2
# ...

# %%
val = 0
# Converting each of the above sentence into numbers
for sentence in text.split("\n"):
    if len(sentence)!=0:
        print(tokenizer.texts_to_sequences([sentence])[0])
        val = val +1
print(val)
# Out:
# [1, 1561, 5, 129, 34]
# [647, 4498, 4499]
# [226, 5, 1562]
# [6, 827, 7, 871]
# [1, 234, 462, 648]
# [6, 110, 5, 2072]
# [1, 678, 1360, 499]
# [1, 294, 949, 872]
# [1, 56, 18, 1, 1014, 873]
# [1, 577, 5, 1, 423, 1361]
# [1, 577, 5, 1, 1785, 763]
# [1, 577, 5, 1, 3185, 649]
# [1, 577, 5, 1, 764, 1246]
# [1, 577, 5, 1, 2073, 394]
# [1, 577, 5, 1, 828, 874]
# [6, 827, 7, 871]
# [226, 5, 1562]
# [1362, 3186]
# [1362, 2488]
# [1362, 3187]
# [1362, 3]
# [4, 129, 34, 37, 14, 215, 1, 210, 3, 16, 1563, 115, 35]
# [3188, 36, 275, 102, 94, 204, 7, 13, 143, 37, 4500, 2]
# [4501, 1, 263, 5, 36, 4502, 9, 12, 25, 8, 10, 335, 102]
# [1786, 2489, 4, 620, 22, 679, 680, 42, 4503, 2, 8, 46]
# [1564, 48, 4504, 4, 13, 500, 2490, 23, 2074]
# [4505, 216, 10, 12, 3, 160, 9, 1, 139, 1363, 950, 2]
# [2075, 681, 8, 1, 726, 58, 176, 23, 17, 6, 1364, 10, 52]
# [16, 578, 171, 7, 6, 2076, 501, 10, 123, 411, 5, 1, 4506]
# [4507, 311, 18, 6, 4508, 2, 6, 1787, 73, 48, 2491, 412]
# ...

# %%
# Creating input & outputs
input_sequences = []
for sentence in faqs.split("\n"):
    
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    
    for i in range(1,len(tokenized_sentence)):
        
        n_gram = tokenized_sentence[:i+1]
        input_sequences.append(n_gram)

# %%
len(input_sequences)
# Out:
# 662

# %%
input_sequences
# Out:
# [[84, 1],
#  [45, 14],
#  [45, 14, 1],
#  [45, 14, 1, 214],
#  [45, 14, 1, 214, 2067],
#  [45, 14, 1, 214, 2067, 22],
#  [45, 14, 1, 214, 2067, 22, 1030],
#  [45, 14, 1, 214, 2067, 22, 1030, 3329],
#  [1, 214],
#  [1, 214, 3411],
#  [1, 214, 3411, 6],
#  [1, 214, 3411, 6, 112],
#  [1, 214, 3411, 6, 112, 11],
#  [1, 214, 3411, 6, 112, 11, 16],
#  [1, 214, 3411, 6, 112, 11, 16, 4],
#  [1, 214, 3411, 6, 112, 11, 16, 4, 173],
#  [1, 214, 3411, 6, 112, 11, 16, 4, 173, 5],
#  [1, 214, 3411, 6, 112, 11, 16, 4, 173, 5, 1463],
#  [45, 14],
#  [45, 14, 1],
#  [45, 14, 1, 6866],
#  [45, 14, 1, 6866, 5],
#  [45, 14, 1, 6866, 5, 1],
#  [45, 14, 1, 6866, 5, 1, 214],
#  [1, 6866],
#  [1, 6866, 5],
#  [1, 6866, 5, 1],
#  [1, 6866, 5, 1, 214],
#  [1, 6866, 5, 1, 214, 14],
#  [1, 6866, 5, 1, 214, 14, 4902],
#  [1, 6866, 5, 1, 214, 14, 4902, 853],
#  [1, 6866, 5, 1, 214, 14, 4902, 853, 33],
#  [1, 6866, 5, 1, 214, 14, 4902, 853, 33, 1],
#  [1, 6866, 5, 1, 214, 14, 4902, 853, 33, 1, 6866],
# ...

# %%
len(input_sequences)
# Out:
# 662

# %%
# In Deep learning all the inputs should have to be of same length
# Hence we have to do a padding so that length is same
max([len(x) for x in input_sequences])
# Out:
# 43

# %%
max_sequence_len = max([len(x) for x in input_sequences])

# %%
max_sequence_len
# Out:
# 43

# %%
# For padding we will use pad_sequences from keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded_input_sequences = np.array(pad_sequences(input_sequences, maxlen = max_sequence_len, padding = "pre"))
padded_input_sequences
# Out:
# array([[   0,    0,    0, ...,    0,   84,    1],
#        [   0,    0,    0, ...,    0,   45,   14],
#        [   0,    0,    0, ...,   45,   14,    1],
#        ...,
#        [   0,    0,    0, ...,    0, 2471, 1522],
#        [   0,    0,    0, ...,    0,   43, 2642],
#        [   0,    0,    0, ...,   43, 2642, 1662]])

# %%
padded_input_sequences.shape
# Out:
# (662, 43)

# %%
# Splitting into input & output
# All columns except the last one as it will be the output
X = padded_input_sequences[:, :-1]
y = padded_input_sequences[:,-1]

# %%
X.shape, y.shape
# Out:
# ((662, 42), (662,))

# %%
# Total number of words that we have
len(tokenizer.word_index)
# Out:
# 8199

# %%
# We have taken 283 instead of 282 in num_classes as tokenizer.word_index starts with 1 not 0
total_num_words = len(tokenizer.word_index)+1

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes = total_num_words)

# %%
#y = np.array(tf.keras.utils.to_categorical(y, num_classes=total_words))

# %%
y.shape
# Out:
# (662, 8200)

# %%
# We have taken 283 instead of 282 in num_classes as tokenizer.word_index starts with 1 not 0
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'i': 3,
#  'to': 4,
#  'of': 5,
#  'a': 6,
#  'in': 7,
#  'that': 8,
#  'it': 9,
#  'he': 10,
#  'you': 11,
#  'was': 12,
#  'his': 13,
#  'is': 14,
#  'my': 15,
#  'have': 16,
#  'as': 17,
#  'with': 18,
#  'had': 19,
#  'which': 20,
#  'at': 21,
#  'for': 22,
#  'but': 23,
#  'me': 24,
#  'not': 25,
#  'be': 26,
#  'we': 27,
#  'from': 28,
#  'there': 29,
#  'this': 30,
#  'said': 31,
#  'upon': 32,
#  'so': 33,
#  'holmes': 34,
#  'him': 35,
#  'her': 36,
#  'she': 37,
#  "'": 38,
#  'very': 39,
#  'your': 40,
#  'been': 41,
#  'all': 42,
#  'on': 43,
#  'no': 44,
#  'what': 45,
#  'one': 46,
#  'then': 47,
#  'were': 48,
#  'by': 49,
#  'are': 50,
#  'an': 51,
#  'would': 52,
#  'out': 53,
#  'when': 54,
#  'up': 55,
#  'man': 56,
#  'could': 57,
#  'has': 58,
#  'do': 59,
#  'into': 60,
#  'mr': 61,
#  'who': 62,
#  'little': 63,
#  'will': 64,
#  'if': 65,
#  'some': 66,
#  'now': 67,
#  'see': 68,
#  'down': 69,
#  'should': 70,
#  'our': 71,
# ...

# %%
# In architecture we will have embedded layer - LSTM layer - Dense Layer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM

# %%
# total_num_words - TOtal vocab count - Number of words
# 100 - Our embedding shape or output dense vector
# max_sequence_len-1 - Input
model = Sequential()
model.add(Embedding(total_num_words,100, input_length = max_sequence_len-1))

# Numer of gates in LSTM nodes hyper parameter - user dependent for better performance
model.add(LSTM(150))

# Dense layer will have exactly same number of nodes as the length of vocab
# For every word you will get the probability & highest word will be the predicted output

model.add(Dense(total_num_words, activation="softmax"))

# %%
#‘total_words’, which represents the total number of distinct words in the vocabulary; 
#‘100’, which denotes the dimensionality of the word embeddings; 
#and ‘input_length’, which specifies the length of the input sequences.

# %%
print(model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_3 (Embedding)     (None, 42, 100)           820000
#
#  lstm_3 (LSTM)               (None, 150)               150600
#
#  dense_3 (Dense)             (None, 8200)              1238200
#
# ...
# Total params: 2208800 (8.43 MB)
# Trainable params: 2208800 (8.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 2s 33ms/step - loss: 1.6619 - accuracy: 0.5740
# Epoch 2/200
# 21/21 [==============================] - 1s 33ms/step - loss: 1.5775 - accuracy: 0.5831
# Epoch 3/200
# 21/21 [==============================] - 1s 33ms/step - loss: 1.5114 - accuracy: 0.5937
# Epoch 4/200
# 21/21 [==============================] - 1s 32ms/step - loss: 1.4776 - accuracy: 0.5967
# Epoch 5/200
# 21/21 [==============================] - 1s 33ms/step - loss: 1.4419 - accuracy: 0.6103
# Epoch 6/200
# 21/21 [==============================] - 1s 34ms/step - loss: 1.4070 - accuracy: 0.6088
# Epoch 7/200
# 21/21 [==============================] - 1s 34ms/step - loss: 1.3810 - accuracy: 0.6193
# Epoch 8/200
# 21/21 [==============================] - 1s 32ms/step - loss: 1.3488 - accuracy: 0.6344
# Epoch 9/200
# 21/21 [==============================] - 1s 33ms/step - loss: 1.3246 - accuracy: 0.6329
# Epoch 10/200
# ...

# %%
seed_text = "To Sherlock"
next_words = 2

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 12ms/step
# To Sherlock the course

# %%
# https://thecleverprogrammer.com/2023/07/17/next-word-prediction-model-using-python/
